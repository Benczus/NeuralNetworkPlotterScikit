# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
from builtins import float
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
import os

# %%
print(os.getcwd())
with open('dataset.csv', mode='r') as infile:
        reader = csv.reader(infile)
        mydict = {rows[0]: rows[1] for rows in reader}
        f_vector_s = list(mydict.keys())
        s_vector_s = list(mydict.values())
        input_vector = np.reshape([float(i) for i in f_vector_s], (-1, 1))
        output_vector = [float(i) for i in s_vector_s]
# Out:
# /home/bogdandy/PycharmProjects/testProject/notebooks

# %%
model = MLPRegressor(hidden_layer_sizes=(50, 20, 30, 40, 50, 60),
                         activation='relu',
                         solver='lbfgs',
                         learning_rate='adaptive',
                         random_state=1,
                         max_iter=1000,
                         learning_rate_init=0.01,
                         alpha=0.01,
                         verbose=True)

# %%
model.fit(input_vector, output_vector)
output_vector_predicted = model.predict(input_vector)
print(model.score(input_vector, output_vector))
plt.subplot(3, 1, 1)
plt.plot(input_vector, output_vector, 'o')
plt.title('')
plt.ylabel('Actual Values(y)')
plt.subplot(3, 1, 2)
plt.plot(input_vector, output_vector_predicted, 'o')
plt.xlabel('x values')
plt.ylabel('Predicted Values(y)')
plt.subplot(3, 1, 3)
plt.plot(input_vector, output_vector, 'o')
plt.plot(input_vector, output_vector_predicted, 'o')
plt.xlabel('x values')
plt.ylabel('Predicted Values(y)')
plt.savefig('plot.pdf')
plt.show()
# Out:
# 0.9997692083366625

# %%
input_train, input_test, output_train, output_test = train_test_split(input_vector, output_vector, test_size=0.33, random_state=42)
model.fit(input_train, output_train)
output_test = model.predict(input_test)
print(model.score(input_vector, output_vector))
plt.subplot(3, 1, 1)
plt.plot(input_train, output_train, 'o')
plt.title('')
plt.ylabel('Actual Values(y)')
plt.subplot(3, 1, 2)
plt.plot(input_test, output_test, 'o')
plt.xlabel('x values')
plt.ylabel('Predicted Values(y)')
plt.subplot(3, 1, 3)
plt.plot(input_train, output_train, 'o')
plt.plot(input_test, output_test, 'o')
plt.xlabel('x values')
plt.ylabel('Predicted Values(y)')
plt.savefig('plot.pdf')
plt.show()
# Out:
# 0.999736024219878
